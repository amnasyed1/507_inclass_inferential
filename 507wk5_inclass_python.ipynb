# %% [markdown]
# <a href="https://colab.research.google.com/github/amnasyed1/507_inclass_inferential/blob/main/507wk5_inclass_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Chi-Square**

# %%
import pandas as pd

import scipy
from scipy.stats import chi2_contingency as chi2

# %%
df = pd.read_csv('cms_data_ordering.csv')
df
# Out:
#                 NPI  LAST_NAME   FIRST_NAME PARTB  DME  HHA  PMD
# 0        1558467555   .MCINDOE       THOMAS     Y    Y    Y    Y
# 1        1417051921    A BELLE            N     Y    Y    Y    Y
# 2        1972040137  A NOVOTNY    ELIZABETH     Y    Y    Y    Y
# 3        1760465553   A SATTAR     MUHAMMAD     Y    Y    Y    Y
# 4        1295400745     A'NEAL       BROGAN     Y    Y    N    N
# ...             ...        ...          ...   ...  ...  ...  ...
# 1508321  1205270725     SNYDER  CHRISTOPHER     Y    Y    Y    Y
# 1508322  1285155580     SNYDER  CHRISTOPHER     Y    Y    Y    Y
# 1508323  1386632016     SNYDER  CHRISTOPHER     Y    Y    Y    Y
# 1508324  1437267655     SNYDER  CHRISTOPHER     Y    Y    Y    Y
# 1508325         159        NaN          NaN   NaN  NaN  NaN  NaN
#
# [1508326 rows x 7 columns]

# %%
65000000/420000
# Out:
# 154.76190476190476

# %%
df['HHA'].value_counts()
# Out:
# Y    1337605
# N     170720
# Name: HHA, dtype: int64

# %%
df['PARTB'].value_counts()
# Out:
# Y    1461901
# N      46424
# Name: PARTB, dtype: int64

# %%
contingency_table = pd.crosstab(df['PARTB'], df['HHA'])
print(contingency_table)
# Out:
# HHA         N        Y
# PARTB
# N       46269      155
# Y      124451  1337450

# %%
chi2, p, _, _ = chi2(contingency_table)
print(f"Chi2 value: {chi2}")
print(f"P-value: {p}")
# Out:
# Chi2 value: 372456.94233684393
# P-value: 0.0

# %%
chi2
# Out:
# 372456.94233684393

# %% [markdown]
# # **T-Test**

# %%
import pandas as pd
from scipy.stats import ttest_ind

# %%
data_cms = pd.read_csv ('https://raw.githubusercontent.com/hantswilliams/HHA_507_2023/main/WK5/examples/data/cms-chronic-conditions/CC_R20_P08_v10_D18_WWDSE_Cond_complete.csv')
data_cms
# Out:
#      Bene_Geo_Lvl Bene_Geo_Desc  Bene_Geo_Cd Bene_Age_Lvl Bene_Demo_Lvl  \
# 0           State       Alabama          1.0          All           All
# 1           State       Alabama          1.0          All           All
# 2           State       Alabama          1.0          All           All
# 3           State       Alabama          1.0          All           All
# 4           State       Alabama          1.0          All           All
# ...           ...           ...          ...          ...           ...
# 1046        State       Wyoming         56.0          All           All
# 1047        State       Wyoming         56.0          All           All
# 1048        State       Wyoming         56.0          All           All
# 1049        State       Wyoming         56.0          All           All
# 1050        State       Wyoming         56.0          All           All
#
#      Bene_Demo_Desc                                    Bene_Cond  Prvlnc  \
# 0               All                                Alcohol Abuse  0.0188
# 1               All                 Alzheimer's Disease/Dementia  0.1140
# 2               All                                    Arthritis  0.3897
# 3               All                                       Asthma  0.0499
# 4               All                          Atrial Fibrillation  0.0793
# ...             ...                                          ...     ...
# 1046            All                                 Hypertension  0.4038
# 1047            All                       Ischemic Heart Disease  0.2010
# 1048            All                                 Osteoporosis  0.0480
# 1049            All  Schizophrenia and Other Psychotic Disorders  0.0154
# 1050            All                                       Stroke  0.0210
#
#       Tot_Mdcr_Stdzd_Pymt_PC  Tot_Mdcr_Pymt_PC  Hosp_Readmsn_Rate  \
# 0                 25102.3405        23348.6039             0.2413
# 1                 25051.8813        22554.0576             0.2119
# 2                 15827.4930        14403.5780             0.1775
# 3                 20560.6948        18914.5834             0.2117
# 4                 25450.4587        23414.3381             0.2268
# ...                      ...               ...                ...
# 1046              14596.5257        16604.1539             0.1563
# 1047              17492.8555        20113.1132             0.1772
# 1048              19099.8147        21672.1663             0.1684
# 1049              16458.9524        18485.6017             0.2006
# 1050              31635.6460        35836.6714             0.1921
#
#       ER_Visits_Per_1000_Benes   is_southern
# 0                    2184.7557      southern
# 1                    1410.8355      southern
# 2                     998.3314      southern
# 3                    1614.4483      southern
# 4                    1450.9822      southern
# ...                        ...           ...
# 1046                 1032.4567  non-southern
# 1047                 1248.6805  non-southern
# 1048                 1137.0338  non-southern
# 1049                 2171.5057  non-southern
# 1050                 2129.5747  non-southern
#
# [1051 rows x 13 columns]

# %%
diabetes_data = data_cms[data_cms['Bene_Cond'] == 'Diabetes']
diabetes_data
# Out:
#      Bene_Geo_Lvl         Bene_Geo_Desc  Bene_Geo_Cd Bene_Age_Lvl  \
# 10          State               Alabama          1.0          All
# 30          State                Alaska          2.0          All
# 50          State               Arizona          4.0          All
# 71          State              Arkansas          5.0          All
# 92          State            California          6.0          All
# 113         State              Colorado          8.0          All
# 134         State           Connecticut          9.0          All
# 155         State              Delaware         10.0          All
# 175         State  District of Columbia         11.0          All
# 196         State               Florida         12.0          All
# 217         State               Georgia         13.0          All
# 237         State                Hawaii         15.0          All
# 256         State                 Idaho         16.0          All
# 276         State              Illinois         17.0          All
# 297         State               Indiana         18.0          All
# 318         State                  Iowa         19.0          All
# 339         State                Kansas         20.0          All
# 360         State              Kentucky         21.0          All
# 381         State             Louisiana         22.0          All
# 402         State                 Maine         23.0          All
# 422         State              Maryland         24.0          All
# 443         State         Massachusetts         25.0          All
# 464         State              Michigan         26.0          All
# 485         State             Minnesota         27.0          All
# 506         State           Mississippi         28.0          All
# 527         State              Missouri         29.0          All
# 547         State               Montana         30.0          All
# 567         State              Nebraska         31.0          All
# 588         State                Nevada         32.0          All
# 609         State         New Hampshire         33.0          All
# 629         State            New Jersey         34.0          All
# 650         State            New Mexico         35.0          All
# 671         State              New York         36.0          All
# 692         State        North Carolina         37.0          All
# 712         State          North Dakota         38.0          All
# 732         State                  Ohio         39.0          All
# 753         State              Oklahoma         40.0          All
# 774         State                Oregon         41.0          All
# 795         State          Pennsylvania         42.0          All
# 815         State          Rhode Island         44.0          All
# 836         State        South Carolina         45.0          All
# 856         State          South Dakota         46.0          All
# 877         State             Tennessee         47.0          All
# 898         State                 Texas         48.0          All
# 918         State                  Utah         49.0          All
# 938         State               Vermont         50.0          All
# 958         State              Virginia         51.0          All
# 979         State            Washington         53.0          All
# 1000        State         West Virginia         54.0          All
# 1021        State             Wisconsin         55.0          All
# 1041        State               Wyoming         56.0          All
#
#      Bene_Demo_Lvl Bene_Demo_Desc Bene_Cond  Prvlnc  Tot_Mdcr_Stdzd_Pymt_PC  \
# 10             All            All  Diabetes  0.3017              16286.6289
# 30             All            All  Diabetes  0.2048              13185.4611
# 50             All            All  Diabetes  0.2274              15076.5501
# 71             All            All  Diabetes  0.2572              15912.5464
# 92             All            All  Diabetes  0.2719              16551.4968
# 113            All            All  Diabetes  0.1829              14794.4503
# 134            All            All  Diabetes  0.2505              16672.2852
# 155            All            All  Diabetes  0.2882              14546.5721
# 175            All            All  Diabetes  0.2881              18276.0011
# 196            All            All  Diabetes  0.2781              18419.2973
# 217            All            All  Diabetes  0.2788              16699.3063
# 237            All            All  Diabetes  0.2709              11980.3482
# 256            All            All  Diabetes  0.2193              13870.3086
# 276            All            All  Diabetes  0.2706              17112.1373
# 297            All            All  Diabetes  0.2784              16204.1618
# 318            All            All  Diabetes  0.2399              13572.8835
# 339            All            All  Diabetes  0.2534              15705.2943
# 360            All            All  Diabetes  0.2934              15748.2175
# 381            All            All  Diabetes  0.2996              19036.2506
# 402            All            All  Diabetes  0.2255              14223.6345
# 422            All            All  Diabetes  0.2957              15515.5852
# 443            All            All  Diabetes  0.2316              15742.5148
# 464            All            All  Diabetes  0.2818              16446.7396
# 485            All            All  Diabetes  0.2133              15106.6591
# 506            All            All  Diabetes  0.3057              17523.4098
# 527            All            All  Diabetes  0.2644              16221.7470
# 547            All            All  Diabetes  0.1877              13272.9443
# 567            All            All  Diabetes  0.2306              15212.9031
# 588            All            All  Diabetes  0.2526              17695.7355
# 609            All            All  Diabetes  0.2154              14177.8642
# 629            All            All  Diabetes  0.3120              16355.4163
# 650            All            All  Diabetes  0.2550              13435.1153
# 671            All            All  Diabetes  0.3134              16044.0998
# 692            All            All  Diabetes  0.2853              14842.7994
# 712            All            All  Diabetes  0.2350              13620.9718
# 732            All            All  Diabetes  0.2720              16494.2988
# 753            All            All  Diabetes  0.2840              17493.3007
# 774            All            All  Diabetes  0.2093              12918.1515
# 795            All            All  Diabetes  0.2585              16247.2099
# 815            All            All  Diabetes  0.2444              14406.3126
# 836            All            All  Diabetes  0.2737              15046.4720
# 856            All            All  Diabetes  0.2265              14449.8241
# 877            All            All  Diabetes  0.2815              16044.4890
# 898            All            All  Diabetes  0.2879              19678.6611
# 918            All            All  Diabetes  0.2381              14120.7648
# 938            All            All  Diabetes  0.2001              12778.4141
# 958            All            All  Diabetes  0.2744              14622.3339
# 979            All            All  Diabetes  0.2177              13415.6060
# 1000           All            All  Diabetes  0.3058              15566.3174
# 1021           All            All  Diabetes  0.2284              14246.4881
# 1041           All            All  Diabetes  0.1986              13430.0211
#
#       Tot_Mdcr_Pymt_PC  Hosp_Readmsn_Rate  ER_Visits_Per_1000_Benes  \
# 10          14858.6123             0.2054                 1021.1721
# 30          17673.4553             0.1791                  970.4527
# 50          16070.5357             0.1986                  873.5951
# 71          14837.7278             0.2131                 1031.6390
# 92          20896.3959             0.2282                  978.6757
# 113         15683.5164             0.1841                  996.7261
# 134         19927.7744             0.2261                 1156.1202
# 155         16113.0152             0.2082                  900.5331
# 175         21865.8637             0.2619                 1518.4258
# 196         18471.6929             0.2301                 1012.9013
# 217         16478.4103             0.2233                 1066.9929
# 237         14394.5945             0.1758                  806.7334
# 256         13926.4167             0.1679                  951.4655
# 276         18133.1987             0.2283                 1051.7994
# 297         16334.3375             0.2107                 1076.6306
# 318         13762.1447             0.1840                  934.3215
# 339         15282.9141             0.1939                  961.5354
# 360         15306.1128             0.2237                 1140.9786
# 381         18128.6357             0.2184                 1210.1268
# 402         14893.5670             0.2024                 1197.1466
# 422         19202.0372             0.2352                  989.2759
# 443         19033.4072             0.2366                 1092.9398
# 464         17226.8028             0.2276                 1138.9964
# 485         16754.4082             0.2175                 1131.5317
# 506         16333.2799             0.2154                 1176.2591
# 527         15963.2372             0.2261                 1071.0488
# 547         14122.3340             0.1768                  950.7069
# 567         15611.8266             0.1930                  831.0846
# 588         19910.6472             0.2486                 1078.7074
# 609         16000.6788             0.2087                 1014.6378
# 629         19292.0649             0.2220                  903.5189
# 650         14058.4280             0.1926                  979.4391
# 671         19869.1643             0.2258                  895.0522
# 692         15075.9386             0.2119                 1103.7099
# 712         13995.8514             0.1990                  861.8680
# 732         16605.4610             0.2195                 1101.6491
# 753         16889.2152             0.2123                 1135.5593
# 774         14604.7105             0.1857                 1000.8307
# 795         17354.1751             0.2210                  973.8960
# 815         16305.0494             0.2322                  961.8712
# 836         14738.5732             0.2074                  967.5885
# 856         14985.8394             0.1888                  836.5157
# 877         15147.7444             0.2149                 1013.9265
# 898         19769.5266             0.2205                 1088.6429
# 918         14451.3925             0.1602                  812.0574
# 938         15296.2775             0.1971                 1110.4859
# 958         14881.6836             0.2100                 1043.6821
# 979         14963.9813             0.1967                  983.9392
# 1000        15349.8626             0.2322                 1218.9660
# 1021        14885.0503             0.2020                 1029.1171
# 1041        15203.8598             0.1745                  952.2263
#
#        is_southern
# 10        southern
# 30    non-southern
# 50    non-southern
# 71        southern
# 92    non-southern
# 113   non-southern
# 134   non-southern
# 155       southern
# 175       southern
# 196       southern
# 217       southern
# 237   non-southern
# 256   non-southern
# 276   non-southern
# 297   non-southern
# 318   non-southern
# 339   non-southern
# 360       southern
# 381       southern
# 402   non-southern
# 422       southern
# 443   non-southern
# 464   non-southern
# 485   non-southern
# 506       southern
# 527   non-southern
# 547   non-southern
# 567   non-southern
# 588   non-southern
# 609   non-southern
# 629   non-southern
# 650   non-southern
# 671   non-southern
# 692       southern
# 712   non-southern
# 732   non-southern
# 753       southern
# 774   non-southern
# 795   non-southern
# 815   non-southern
# 836       southern
# 856   non-southern
# 877       southern
# 898       southern
# 918   non-southern
# 938   non-southern
# 958       southern
# 979   non-southern
# 1000      southern
# 1021  non-southern
# 1041  non-southern

# %%
# Split the data into two groups: southern and non-southern
southern_data = diabetes_data[diabetes_data['is_southern'] == 'southern']['Prvlnc']
southern_data
# Out:
# 10      0.3017
# 71      0.2572
# 155     0.2882
# 175     0.2881
# 196     0.2781
# 217     0.2788
# 360     0.2934
# 381     0.2996
# 422     0.2957
# 506     0.3057
# 692     0.2853
# 753     0.2840
# 836     0.2737
# 877     0.2815
# 898     0.2879
# 958     0.2744
# 1000    0.3058
# Name: Prvlnc, dtype: float64

# %%
non_southern_data = diabetes_data[diabetes_data['is_southern'] == 'non-southern']['Prvlnc'] # noqa
non_southern_data
# Out:
# 30      0.2048
# 50      0.2274
# 92      0.2719
# 113     0.1829
# 134     0.2505
# 237     0.2709
# 256     0.2193
# 276     0.2706
# 297     0.2784
# 318     0.2399
# 339     0.2534
# 402     0.2255
# 443     0.2316
# 464     0.2818
# 485     0.2133
# 527     0.2644
# 547     0.1877
# 567     0.2306
# 588     0.2526
# 609     0.2154
# 629     0.3120
# 650     0.2550
# 671     0.3134
# 712     0.2350
# 732     0.2720
# 774     0.2093
# 795     0.2585
# 815     0.2444
# 856     0.2265
# 918     0.2381
# 938     0.2001
# 979     0.2177
# 1021    0.2284
# 1041    0.1986
# Name: Prvlnc, dtype: float64

# %%
t_stat, p_val = ttest_ind(southern_data, non_southern_data)

# %%
t_stat, p_val = ttest_ind(southern_data, non_southern_data, equal_var=False)  # Assuming unequal variances with Welch's t-test # noqa

# %%
print(f"T-statistic: {t_stat}")
print(f"P-value: {p_val}")
# Out:
# T-statistic: 7.3443010290424295
# P-value: 2.3414774247466913e-09

# %%
# Compute means for southern and non-southern data
southern_mean = southern_data.mean()
non_southern_mean = non_southern_data.mean()

print(f"Mean prevalence for southern states: {southern_mean}")
print(f"Mean prevalence for non-southern states: {non_southern_mean}")
# Out:
# Mean prevalence for southern states: 0.2870058823529411
# Mean prevalence for non-southern states: 0.2406441176470588

# %%
# or you can find the mean this way:
non_southern_data = diabetes_data[diabetes_data['is_southern'] == 'non-southern']['Prvlnc'] # noqa
non_southern_data_mean = non_southern_data.mean()
non_southern_data_mean
# and then do the same for the southern states
# Out:
# 0.2406441176470588

# %%
# Read in the data
data_cms = pd.read_csv('https://raw.githubusercontent.com/hantswilliams/HHA_507_2023/main/WK5/examples/data/cms-chronic-conditions/CC_R20_P08_v10_D18_WWDSE_Cond_complete.csv') # noqa
len(df)

## keep only complete rows
data_cms = df.dropna()
len(df)
# Out:
# 1051

# %%
## create a new binary variable based on the Bene_Geo_Desc variable, where the value will be southern or non-southern # noqa
## southern states are: Alabama, Arkansas, Delaware, District of Columbia, Florida, Georgia, Kentucky, Louisiana, Maryland, Mississippi, North Carolina, Oklahoma, South Carolina, Tennessee, Texas, Virginia, West Virginia #noqa
## non-southern states are: Alaska, Arizona, California, Colorado, Connecticut, Hawaii, Idaho, Illinois, Indiana,
## Iowa, Kansas, Maine, Massachusetts, Michigan, Minnesota, Missouri, Montana, Nebraska, Nevada, New Hampshire, New Jersey,
## New Mexico, New York, North Dakota, Ohio, Oregon, Pennsylvania, Rhode Island, South Dakota, Utah, Vermont, Washington,
## Wisconsin, Wyoming

## create a new variable called southern
data_cms['is_southern'] = data_cms['Bene_Geo_Desc'].apply(lambda x: 'southern' if x in ['Alabama',
        'Arkansas', 'Delaware', 'District of Columbia', 'Florida', 'Georgia',
        'Kentucky', 'Louisiana', 'Maryland', 'Mississippi', 'North Carolina',
        'Oklahoma', 'South Carolina', 'Tennessee', 'Texas', 'Virginia',
        'West Virginia'] else 'non-southern')
df
# Out:
#      Bene_Geo_Lvl Bene_Geo_Desc  Bene_Geo_Cd Bene_Age_Lvl Bene_Demo_Lvl  \
# 0           State       Alabama          1.0          All           All
# 1           State       Alabama          1.0          All           All
# 2           State       Alabama          1.0          All           All
# 3           State       Alabama          1.0          All           All
# 4           State       Alabama          1.0          All           All
# ...           ...           ...          ...          ...           ...
# 1046        State       Wyoming         56.0          All           All
# 1047        State       Wyoming         56.0          All           All
# 1048        State       Wyoming         56.0          All           All
# 1049        State       Wyoming         56.0          All           All
# 1050        State       Wyoming         56.0          All           All
#
#      Bene_Demo_Desc                                    Bene_Cond  Prvlnc  \
# 0               All                                Alcohol Abuse  0.0188
# 1               All                 Alzheimer's Disease/Dementia  0.1140
# 2               All                                    Arthritis  0.3897
# 3               All                                       Asthma  0.0499
# 4               All                          Atrial Fibrillation  0.0793
# ...             ...                                          ...     ...
# 1046            All                                 Hypertension  0.4038
# 1047            All                       Ischemic Heart Disease  0.2010
# 1048            All                                 Osteoporosis  0.0480
# 1049            All  Schizophrenia and Other Psychotic Disorders  0.0154
# 1050            All                                       Stroke  0.0210
#
#       Tot_Mdcr_Stdzd_Pymt_PC  Tot_Mdcr_Pymt_PC  Hosp_Readmsn_Rate  \
# 0                 25102.3405        23348.6039             0.2413
# 1                 25051.8813        22554.0576             0.2119
# 2                 15827.4930        14403.5780             0.1775
# 3                 20560.6948        18914.5834             0.2117
# 4                 25450.4587        23414.3381             0.2268
# ...                      ...               ...                ...
# 1046              14596.5257        16604.1539             0.1563
# 1047              17492.8555        20113.1132             0.1772
# 1048              19099.8147        21672.1663             0.1684
# 1049              16458.9524        18485.6017             0.2006
# 1050              31635.6460        35836.6714             0.1921
#
#       ER_Visits_Per_1000_Benes   is_southern
# 0                    2184.7557      southern
# 1                    1410.8355      southern
# 2                     998.3314      southern
# 3                    1614.4483      southern
# 4                    1450.9822      southern
# ...                        ...           ...
# 1046                 1032.4567  non-southern
# 1047                 1248.6805  non-southern
# 1048                 1137.0338  non-southern
# 1049                 2171.5057  non-southern
# 1050                 2129.5747  non-southern
#
# [1051 rows x 13 columns]

# %% [markdown]
# # **ANOVA**

# %%
opioids = pd.read_csv('https://raw.githubusercontent.com/hantswilliams/HHA_507_2023/main/WK5/examples/data/nys-opioid-visits/sparcs_opioid_clean.csv')
opioids
# Out:
#      rural_urban     payer  overall_opioid
# 0          Urban  Medicaid              38
# 1          Urban  Medicare              27
# 2          Rural  Medicaid               3
# 3          Rural  Medicaid               2
# 4          Rural     Other               1
# ...          ...       ...             ...
# 1909       Urban   Unknown               0
# 1910       Rural   Unknown               4
# 1911       Rural   Unknown               1
# 1912       Urban   Unknown               0
# 1913       Urban   Unknown               0
#
# [1914 rows x 3 columns]

# %%
import statsmodels.api as sm
from statsmodels.formula.api import ols

# %%
model = ols('overall_opioid ~ C(payer) * C(rural_urban)', data=opioids).fit()
model

# %%
# Performing the two-way ANOVA
anova_table = sm.stats.anova_lm(model, typ=2)

print(anova_table)
# Out:
#                                sum_sq      df           F        PR(>F)
# C(payer)                 9.573150e+05     4.0   76.381109  3.918643e-60
# C(rural_urban)           5.357190e+05     1.0  170.973254  1.772630e-37
# C(payer):C(rural_urban)  3.805419e+05     4.0   30.362222  1.580212e-24
# Residual                 5.965898e+06  1904.0         NaN           NaN

# %% [markdown]
# all p values above are extremely small

# %%
# instead of the *, replaced it with a +
model = ols('overall_opioid ~ C(payer) + C(rural_urban)', data=opioids).fit()
model

# %%
# Performing the two-way ANOVA
anova_table = sm.stats.anova_lm(model, typ=2)

print(anova_table)
# Out:
#                       sum_sq      df           F        PR(>F)
# C(payer)        9.573150e+05     4.0   71.952028  7.784636e-57
# C(rural_urban)  5.357190e+05     1.0  161.059097  1.728852e-35
# Residual        6.346440e+06  1908.0         NaN           NaN
